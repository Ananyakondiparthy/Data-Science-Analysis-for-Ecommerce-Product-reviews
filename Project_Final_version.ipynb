# %% [markdown]
# # Python Project
# ## Women's E-commerce data

# %%
#Required packages
import pandas as pd
import numpy as np
import seaborn as sns
# %pylab inline
import os     

import sklearn as sk
import sklearn.tree as tree
from IPython.display import Image  
import pydotplus

import warnings
warnings.filterwarnings('ignore')

import re
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### About Dataset
#
# This is a Women’s Clothing E-Commerce dataset revolving around the reviews written by customers. Its nine supportive features offer a great environment to parse out the text through its multiple dimensions. Because this is real commercial data, it has been anonymized, and references to the company in the review text and body have been replaced with “retailer”.

# %% [markdown]
# This dataset includes 23486 rows and 10 feature variables. Each row corresponds to a customer review, and includes the variables:
# <ul>
#     <li>Clothing ID: Integer Categorical variable that refers to the specific piece being reviewed.</li>
#     <li>Age: Positive Integer variable of the reviewers age.</li>
#     <li>Title: String variable for the title of the review.</li>
#     <li>Review Text: String variable for the review body.</li>
#     <li>Rating: Positive Ordinal Integer variable for the product score granted by the customer from 1 Worst, to 5 Best.</li>
#     <li>Recommended IND: Binary variable stating where the customer recommends the product where 1 is recommended, 0 is not recommended.</li>
#     <li>Positive Feedback Count: Positive Integer documenting the number of other customers who found this review positive.</li>
#     <li>Division Name: Categorical name of the product high level division.</li>
#     <li>Department Name: Categorical name of the product department name.</li>
#     <li>Class Name: Categorical name of the product class name.</li>
# </ul>

# %%
#Reading the data & renaming the columns
df = pd.read_csv('Womens Clothing E-Commerce Reviews.csv',index_col=0)
df.columns=['clothing_ID',
            'age',
            'review_title',
            'review_text',
            'rating',
            'recommended_IND',
            'positive_feedback_count',
            'division_name',
            'dept_name',
            'class_name'
           ]
df.head()
# Out:
#    clothing_ID  age             review_title  \
# 0          767   33                      NaN
# 1         1080   34                      NaN
# 2         1077   60  Some major design flaws
# 3         1049   50         My favorite buy!
# 4          847   47         Flattering shirt
#
#                                          review_text  rating  recommended_IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    positive_feedback_count   division_name dept_name class_name
# 0                        0       Initmates  Intimate  Intimates
# 1                        4         General   Dresses    Dresses
# 2                        0         General   Dresses    Dresses
# 3                        0  General Petite   Bottoms      Pants
# 4                        6         General      Tops    Blouses

# %% [markdown]
# ##### Data Cleaning

# %%
df.isna().sum()
# Out:
# clothing_ID                   0
# age                           0
# review_title               3810
# review_text                 845
# rating                        0
# recommended_IND               0
# positive_feedback_count       0
# division_name                14
# dept_name                    14
# class_name                   14
# dtype: int64

# %% [markdown]
# Removing columns that are not being used.

# %%
df.drop('review_title', axis = 1,inplace = True)

# %% [markdown]
# Removing the rows with na values

# %%
df.dropna(how = 'any', subset = ['dept_name'], inplace = True)

# %% [markdown]
# ##### Exploring Dataset

# %%
df.describe()
# Out:
#         clothing_ID           age        rating  recommended_IND  \
# count  23472.000000  23472.000000  23472.000000     23472.000000
# mean     918.486665     43.200707      4.195552         0.822256
# std      202.727678     12.280913      1.110188         0.382305
# min        0.000000     18.000000      1.000000         0.000000
# 25%      861.000000     34.000000      4.000000         1.000000
# 50%      936.000000     41.000000      5.000000         1.000000
# 75%     1078.000000     52.000000      5.000000         1.000000
# max     1205.000000     99.000000      5.000000         1.000000
#
#        positive_feedback_count
# count             23472.000000
# mean                  2.537151
# std                   5.703597
# min                   0.000000
# 25%                   0.000000
# 50%                   1.000000
# 75%                   3.000000
# max                 122.000000

# %%
df.corr()
# Out:
#                          clothing_ID       age    rating  recommended_IND  \
# clothing_ID                 1.000000  0.017322 -0.017626        -0.015414
# age                         0.017322  1.000000  0.026967         0.030712
# rating                     -0.017626  0.026967  1.000000         0.792311
# recommended_IND            -0.015414  0.030712  0.792311         1.000000
# positive_feedback_count     0.045875  0.043049 -0.064820        -0.068954
#
#                          positive_feedback_count
# clothing_ID                             0.045875
# age                                     0.043049
# rating                                 -0.064820
# recommended_IND                        -0.068954
# positive_feedback_count                 1.000000

# %%
sns.heatmap(df.corr() , cmap=sns.diverging_palette(20, 220, n=256) , square=True)
plt.savefig('corr.png', dpi = 500, format = 'png')

# %% [markdown]
# ### Finding 1: Distribution of Age of people who reviewed the purchased products.

# %% [markdown]
# ##### Univariate Analysis

# %%
fig, ax = plt.subplots(1,figsize=(10, 5))   # figure and axes .
sns.distplot(df.age, bins = 20)
ax.set_title('Age Distribution')
ax.set_ylabel('Density Percent')
# Out:
# Text(0, 0.5, 'Density Percent')

# %% [markdown]
# Insight:
# a. The resulted age group is the most active in purchasing the products and reviewing them. So, the business must concentrate on keeping up with this fragment and
# b. The e-commerce business element can investigate why other age groups are relatively less than the age group 31 to 45.

# %%
sns.countplot(df.rating)

# %%
sns.countplot(df.recommended_IND)

# %% [markdown]
# ##### Bivariate Analysis

# %%
Total_feedbck_count = df.groupby(['clothing_ID','age'], as_index = False).\
                                    agg({'positive_feedback_count': 'sum'})

# %%
Total_feedbck_count.sort_values(by = ['clothing_ID','positive_feedback_count'], ascending = False)
# Out:
#       clothing_ID  age  positive_feedback_count
# 8786         1205   34                        0
# 8787         1205   69                        0
# 8785         1204   39                        3
# 8783         1203   53                        1
# 8784         1203   54                        1
# 8776         1203   27                        0
# 8777         1203   29                        0
# 8778         1203   30                        0
# 8779         1203   34                        0
# 8780         1203   37                        0
# 8781         1203   43                        0
# 8782         1203   47                        0
# 8771         1202   44                        2
# 8772         1202   45                        1
# 8775         1202   65                        1
# 8767         1202   28                        0
# 8768         1202   30                        0
# 8769         1202   31                        0
# 8770         1202   32                        0
# 8773         1202   48                        0
# 8774         1202   55                        0
# 8765         1201   35                        0
# 8766         1201   38                        0
# 8764         1200   24                        0
# 8763         1199   31                        0
# 8761         1198   25                        0
# 8762         1198   68                        0
# 8760         1197   68                        1
# 8758         1197   55                        0
# 8759         1197   60                        0
# ...           ...  ...                      ...
# 29             21   55                        0
# 28             20   34                        0
# 27             19   21                        0
# 26             18   42                        0
# 25             17   31                        0
# 24             16   39                        0
# 22             15   34                        0
# 23             15   45                        0
# 21             14   32                        0
# 20             13   39                        0
# 19             12   28                        0
# 18             11   46                        0
# 17             10   38                        0
# 16              9   34                        0
# 10              8   33                        2
# 11              8   36                        0
# 12              8   38                        0
# 13              8   42                        0
# 14              8   57                        0
# 15              8   70                        0
# 9               7   39                        0
# 8               6   39                        0
# 7               5   39                        0
# 6               4   28                        0
# 5               3   36                        0
# 4               2   28                        0
# 1               1   24                        1
# 2               1   36                        0
# 3               1   50                        0
# 0               0   26                        0
#
# [8788 rows x 3 columns]

# %%
Total_feedbck_count[Total_feedbck_count.clothing_ID == 1078].\
           sort_values(by = ['clothing_ID','positive_feedback_count'], ascending = False)
# Out:
#       clothing_ID  age  positive_feedback_count
# 7279         1078   39                      217
# 7286         1078   46                      170
# 7263         1078   23                      133
# 7276         1078   36                      123
# 7292         1078   52                      110
# 7274         1078   34                      102
# 7293         1078   53                      101
# 7275         1078   35                      100
# 7284         1078   44                       99
# 7267         1078   27                       85
# 7281         1078   41                       78
# 7266         1078   26                       77
# 7282         1078   42                       77
# 7268         1078   28                       74
# 7273         1078   33                       73
# 7291         1078   51                       67
# 7296         1078   56                       65
# 7302         1078   62                       62
# 7303         1078   63                       62
# 7283         1078   43                       61
# 7277         1078   37                       59
# 7288         1078   48                       59
# 7298         1078   58                       53
# 7280         1078   40                       50
# 7285         1078   45                       49
# 7287         1078   47                       49
# 7278         1078   38                       48
# 7297         1078   57                       40
# 7269         1078   29                       38
# 7304         1078   64                       38
# ...           ...  ...                      ...
# 7270         1078   30                       23
# 7300         1078   60                       21
# 7259         1078   19                       18
# 7305         1078   65                       18
# 7309         1078   69                       17
# 7265         1078   25                       16
# 7289         1078   49                       16
# 7307         1078   67                       14
# 7264         1078   24                        9
# 7262         1078   22                        8
# 7310         1078   70                        8
# 7260         1078   20                        7
# 7294         1078   54                        7
# 7308         1078   68                        6
# 7306         1078   66                        5
# 7319         1078   82                        5
# 7295         1078   55                        2
# 7299         1078   59                        2
# 7312         1078   72                        2
# 7315         1078   75                        1
# 7316         1078   77                        1
# 7317         1078   78                        1
# 7318         1078   79                        1
# 7320         1078   83                        1
# 7322         1078   99                        1
# 7261         1078   21                        0
# 7311         1078   71                        0
# 7313         1078   73                        0
# 7314         1078   74                        0
# 7321         1078   84                        0
#
# [64 rows x 3 columns]

# %%
Total_feedbck_count.sort_values(by = ['clothing_ID','positive_feedback_count'], ascending = False).\
                                nlargest(10,'positive_feedback_count')
# Out:
#       clothing_ID  age  positive_feedback_count
# 7279         1078   39                      217
# 7894         1094   39                      205
# 7286         1078   46                      170
# 7891         1094   36                      160
# 7943         1095   29                      151
# 3454          867   56                      149
# 7426         1081   39                      146
# 7263         1078   23                      133
# 3191          862   39                      131
# 7892         1094   37                      128

# %%
fig, ax = plt.subplots(1,figsize=(6, 4))   # figure and axes .
sns.distplot(Total_feedbck_count.positive_feedback_count)
ax.set_title('Positive Feedback Count Distribution')
ax.set_ylabel('Density Percent')
# Out:
# Text(0, 0.5, 'Density Percent')

# %% [markdown]
# binning Age

# %%
df['age_bin'] = pd.cut(df.age , bins = 6)
df.groupby('age_bin').rating.mean()
# Out:
# age_bin
# (17.919, 31.5]    4.176953
# (31.5, 45.0]      4.177461
# (45.0, 58.5]      4.189526
# (58.5, 72.0]      4.294744
# (72.0, 85.5]      4.264591
# (85.5, 99.0]      4.230769
# Name: rating, dtype: float64

# %%
f = sns.catplot(x='age_bin', y='rating',data = df, kind='bar', aspect = 2)
f.fig.suptitle("Age vs Rating")
#plt.savefig('positivefeedback-age.png', format='png', dpi=300)
plt.show()

# %% [markdown]
# ###### Which age group is preferring which departments(dept_name)

# %% [raw]
# Grouping age in equal frequency parts

# %%
df['age_group'] = pd.qcut(df.age, 12)

# %%
g = sns.catplot(x='age_bin', data = df, y='positive_feedback_count', kind='bar', color='b',aspect = 3)
g.fig.suptitle("Scatter Plot for Age and Positive Feedback Count")
plt.show()

# %% [markdown]
# ###### Age Versus Positive Feedback Count.

# %%
g = sns.factorplot(x='age_group', data = df, y='positive_feedback_count', kind='bar', color='b', aspect = 3)
g.fig.suptitle("Scatter Plot for Age and Positive Feedback Count")
#plt.savefig('positivefeedback-age.png', format='png', dpi=300)
plt.show()

# %%
series_age_dept = df.groupby(['dept_name','age_group']).size()
series_age_dept
# Out:
# dept_name  age_group
# Bottoms    (17.999, 27.0]     290
#            (27.0, 32.0]       407
#            (32.0, 34.0]       248
#            (34.0, 37.0]       392
#            (37.0, 39.0]       349
#            (39.0, 41.0]       256
#            (41.0, 44.0]       306
#            (44.0, 48.0]       431
#            (48.0, 52.0]       263
#            (52.0, 56.0]       276
#            (56.0, 62.0]       325
#            (62.0, 99.0]       256
# Dresses    (17.999, 27.0]     584
#            (27.0, 32.0]       786
#            (32.0, 34.0]       427
#            (34.0, 37.0]       693
#            (37.0, 39.0]       624
#            (39.0, 41.0]       351
#            (41.0, 44.0]       500
#            (44.0, 48.0]       626
#            (48.0, 52.0]       444
#            (52.0, 56.0]       441
#            (56.0, 62.0]       447
#            (62.0, 99.0]       396
# Intimate   (17.999, 27.0]     194
#            (27.0, 32.0]       240
#            (32.0, 34.0]       129
#            (34.0, 37.0]       226
#            (37.0, 39.0]       141
#            (39.0, 41.0]        94
#                              ...
# Jackets    (41.0, 44.0]        71
#            (44.0, 48.0]        90
#            (48.0, 52.0]        81
#            (52.0, 56.0]        73
#            (56.0, 62.0]        96
#            (62.0, 99.0]       106
# Tops       (17.999, 27.0]     818
#            (27.0, 32.0]      1000
#            (32.0, 34.0]       640
#            (34.0, 37.0]      1076
#            (37.0, 39.0]       851
#            (39.0, 41.0]       596
#            (41.0, 44.0]       854
#            (44.0, 48.0]      1104
#            (48.0, 52.0]       802
#            (52.0, 56.0]       853
#            (56.0, 62.0]       888
#            (62.0, 99.0]       986
# Trend      (17.999, 27.0]      11
#            (27.0, 32.0]         6
#            (32.0, 34.0]         4
#            (34.0, 37.0]        16
#            (37.0, 39.0]        13
#            (39.0, 41.0]         6
#            (41.0, 44.0]        11
#            (44.0, 48.0]        10
#            (48.0, 52.0]        11
#            (52.0, 56.0]        13
#            (56.0, 62.0]         8
#            (62.0, 99.0]        10
# Length: 72, dtype: int64

# %% [markdown]
# ### Finding 2: Frequency Distribution of Departments According to the Age Groups

# %%
age_dept = pd.DataFrame(series_age_dept).reset_index().rename(columns={0:'size'})
sns.catplot(data=age_dept, x='size', y='age_group', hue ='dept_name' ,kind = 'bar', height = 10)

# %% [markdown]
# Insight : One of the reasons might be the product is offered in several apparel sizes, which attracts all age group people for a specific department. This finding can measure product reviews and sales based on the category department.

# %% [markdown]
# ###### Distribution of Age Range To The Total Recommendations

# %%
series_age_recommended = df.groupby('age_group')['recommended_IND'].sum().copy()
series_age_recommended
# Out:
# age_group
# (17.999, 27.0]    1669
# (27.0, 32.0]      2019
# (32.0, 34.0]      1222
# (34.0, 37.0]      2022
# (37.0, 39.0]      1722
# (39.0, 41.0]      1117
# (41.0, 44.0]      1485
# (44.0, 48.0]      1960
# (48.0, 52.0]      1437
# (52.0, 56.0]      1463
# (56.0, 62.0]      1596
# (62.0, 99.0]      1588
# Name: recommended_IND, dtype: int64

# %%
newdata = pd.DataFrame(series_age_recommended).reset_index()
newdata
# Out:
#          age_group  recommended_IND
# 0   (17.999, 27.0]             1669
# 1     (27.0, 32.0]             2019
# 2     (32.0, 34.0]             1222
# 3     (34.0, 37.0]             2022
# 4     (37.0, 39.0]             1722
# 5     (39.0, 41.0]             1117
# 6     (41.0, 44.0]             1485
# 7     (44.0, 48.0]             1960
# 8     (48.0, 52.0]             1437
# 9     (52.0, 56.0]             1463
# 10    (56.0, 62.0]             1596
# 11    (62.0, 99.0]             1588

# %%
sns.catplot(data=newdata, x='recommended_IND', y='age_group', kind = 'bar')

# %% [markdown]
# ##### Sentiment Analysis

# %%
negative=open("sad.txt",'r', encoding = "ISO-8859-1")
negativ=negative.read().lower().split()

positive=open("happy.txt",'r', encoding = "ISO-8859-1")
positiv=positive.read().lower().split()

# %%
#used for tagging the sentiment

def giveSentiment(reviews):

    review= clean(reviews)
    score=0 # keeping the score value
    total_words=0 # tatal words analyzed
    positive=0 # total positive word 
    negative =0 # total negative word 
    count=0
    flag=0.5
    for x in review:
        
        if x in negativ:# words with negative effect are scored -1
            
            score-=1
            total_words+=1
            negative+=1
            flag=0 #flag captures the recent sentiment 
        
        elif x in positiv:# words with positive effect are scored +1
            
            score+=1
            total_words+=1
            positive+=1
            flag=1
    
        elif x=="!": # this block of code calculates the effect of !

            count+=1
            i=review.index(x)
            if review[i-1] in negativ:
                #print("!-")
                score-=1
                total_words+=1
            elif review[i-1] in positiv:
                #print("!+")
                score+=1
                total_words+=1
            else:
                pass
        
        
        elif x=="?": # this block of code calculates the effect of ?
            count+=1
            if flag==0:
                score-=1
                total_words+=1
            elif flag==1:
                total_words+=1
                score+=1
            else:
                pass

        
        elif x=="so" or x=="too" or x=="very":# this block of code calculates the effect of  "so","too","very"
            count+=1
            i=review.index(x)
            if (review.index(x)== len(review))|(review[review.index(x)]== review[-1]):
                break
            elif review[i+1] in negativ:

                score-=1
                total_words+=1
            elif review[i+1] in positiv:
  
                score+=1
                total_words+=1
            else:
                pass
     
        elif x=="not" :# this block of code calculates the effect of "not", the approach used is that the upcoming effect is reversed
            #print("#")
            count+=1
            i=review.index(x)

            if (review.index(x)== len(review))|(review[review.index(x)]== review[-1]):
                break
            elif review[i+1] in negativ:
                score+=3 #a score of 3 is added because the effect of the upcoming word has reversed,it consists two scores 1:for the supportive word itself 2:for the upcoming sentiment
                total_words+=1
            elif review[i+1] in positiv:
                score-=3 #score of -3 is added because the effect of the upcoming word has reversed,it consists two scores -1:for the supportive word itself -2:for the upcoming sentiment
                total_words+=1
            else:
                pass   
    
    final = score/len(review)
    
    if final <0:
        return -1
    elif final==0:
        return 0
    else:
        return 1

# %%
def clean(n):
    m = re.sub(r"[^a-zA-Z!?]", " ",str(n).lower())
    m = m.replace(" be ", " ").replace(" on ", " ").replace(" to ", " ").replace(" is ", " ").\
        replace(" are ", " ").replace(" was ", " ").replace(" were ", " ").replace(' a '," ").replace(' an '," ").\
        replace(" the "," ").split()
    return(m)

# %% [markdown]
# Calculating the sentiment score for each Review

# %%
df["Sentiment_score"]=df['review_text'].apply(giveSentiment)

# %%
df["Sentiment_score"][df.review_text.isna()] = 99

# %%
def define_sentiment(i):
    if (i == 1):
        return 'Positive' 
    elif (i == 0): 
        return 'Neutral' 
    elif (i == -1):
        return 'Negative'

# %%
df['Sentiment_label'] = df.Sentiment_score.apply(define_sentiment)

# %%
sns.countplot(df.Sentiment_label)

# %% [markdown]
# ### Finding 3: Summary for Finding 3: Distribution of Sentiment Scores Vs Rating Vs Recommended Indicator across Reviews.

# %%
sns.catplot(data=df,x='rating',y='recommended_IND', hue = 'Sentiment_score',
           kind='bar',aspect=2)

# %% [markdown]
# Insight: From this e-Commerce we get a sense of what is not working and make necessary changes to improve the shopping experience of the customer. It also gives the company the insight as to how customers perceive their products and/or services and would give them an idea on how to improve their business.

# %% [markdown]
# ### Checking the most occuring words in positive and negative words

# %% [markdown]
# We have seen the sentiment analysis for each of the reviews is done. Most were positive while others were neutral or negative. It could be interesting to what were the words that occured the most in those reviews. We have used word cloud technique to create a pictorial representation of most used words.

# %%
df_word = df.copy()
stop_words = set(stopwords.words('english'))

# %%
def filter_reviews_text(review_str):
    
    mystr = ' '.join(clean(review_str))
    all_words = word_tokenize(mystr)
    filtered_words = ''
 
    for w in all_words:
        if w not in stop_words:
            filtered_words += ' ' + w
    
    return filtered_words

# %%
df_word['filtered_text'] = df_word['review_text'].apply(filter_reviews_text)
df_word.head(5)
# Out:
#    clothing_ID  age                                        review_text  \
# 0          767   33  Absolutely wonderful - silky and sexy and comf...
# 1         1080   34  Love this dress!  it's sooo pretty.  i happene...
# 2         1077   60  I had such high hopes for this dress and reall...
# 3         1049   50  I love, love, love this jumpsuit. it's fun, fl...
# 4          847   47  This shirt is very flattering to all due to th...
#
#    rating  recommended_IND  positive_feedback_count   division_name dept_name  \
# 0       4                1                        0       Initmates  Intimate
# 1       5                1                        4         General   Dresses
# 2       3                0                        0         General   Dresses
# 3       5                1                        0  General Petite   Bottoms
# 4       5                1                        6         General      Tops
#
#   class_name       age_bin     age_group  Sentiment_score  \
# 0  Intimates  (31.5, 45.0]  (32.0, 34.0]                1
# 1    Dresses  (31.5, 45.0]  (32.0, 34.0]                1
# 2    Dresses  (58.5, 72.0]  (56.0, 62.0]                1
# 3      Pants  (45.0, 58.5]  (48.0, 52.0]                1
# 4    Blouses  (45.0, 58.5]  (44.0, 48.0]                1
#
#                                        filtered_text
# 0        absolutely wonderful silky sexy comfortable
# 1   love dress ! sooo pretty happened find store ...
# 2   high hopes dress really wanted work initially...
# 3   love love love jumpsuit fun flirty fabulous !...
# 4   shirt flattering due adjustable front tie per...

# %% [markdown]
# ##### Word cloud for reviews where rating is less than or equal to 2 and sentiment is negative

# %%
df_n_score = df_word[(df_word.rating <= 2) & (df_word.Sentiment_score == -1)]

# %%
vectorizer1 = CountVectorizer()
X_nscore = vectorizer1.fit_transform(df_n_score.filtered_text)
num1=X_nscore.toarray().sum(axis=0)
wor1=vectorizer1.get_feature_names()
list_tuples = list(zip(wor1, num1))

df_count_nscore = pd.DataFrame(list_tuples, columns = ['wor1', 'num1'])
df_count_nscore=df_count_nscore.set_index('wor1')
df_count_nscore = df_count_nscore.num1.nlargest(50)

n_wordcloud = WordCloud(collocations = False, width=800, height=500, 
  background_color="white").generate(str(df_count_nscore).lstrip('wor1'))

plt.figure(figsize=(10, 7))
plt.imshow(n_wordcloud, interpolation="bilinear")
plt.axis('off')

plt.show()

# %% [markdown]
# ##### Word cloud for reviews where rating is more than 3 and sentiment is positive

# %%
df_n_score = df_word[(df_word.rating >3) & (df_word.Sentiment_score == 1)]

# %%
vectorizer1 = CountVectorizer()
X_nscore = vectorizer1.fit_transform(df_n_score.filtered_text)
num1=X_nscore.toarray().sum(axis=0)
wor1=vectorizer1.get_feature_names()
list_tuples = list(zip(wor1, num1))

df_count_nscore = pd.DataFrame(list_tuples, columns = ['wor1', 'num1'])
df_count_nscore=df_count_nscore.set_index('wor1')
df_count_nscore = df_count_nscore.num1.nlargest(50)

n_wordcloud = WordCloud(collocations = False, width=800, height=500, 
  background_color="white").generate(str(df_count_nscore).lstrip('wor1'))

plt.figure(figsize=(10, 7))
plt.imshow(n_wordcloud, interpolation="bilinear")
plt.axis('off')

plt.show()

# %% [markdown]
# ### Finding 4: Distribution of Products Based on Recommendation Factor

# %% [markdown]
# ##### Why is recommendations important?

# %%
df_recommendations = df.groupby('clothing_ID', as_index=False).recommended_IND.agg(['size','sum']).rename(columns={\
    'size':'times_purchased','sum':'Number_of_times_recommended'}).sort_values('times_purchased',ascending = False).head(20)

# %%
df_recommendations
# Out:
#              times_purchased  Number_of_times_recommended
# clothing_ID
# 1078                    1024                          841
# 862                      806                          661
# 1094                     756                          621
# 1081                     582                          494
# 872                      545                          478
# 829                      527                          436
# 1110                     480                          403
# 868                      430                          325
# 895                      404                          341
# 936                      358                          294
# 867                      351                          285
# 850                      338                          294
# 1095                     327                          259
# 863                      306                          260
# 1077                     297                          237
# 1059                     294                          238
# 1086                     291                          242
# 1080                     289                          242
# 860                      288                          231
# 1083                     249                          213

# %% [markdown]
# Insight : The clothing_id which are more recommended, are the ones that are purchased more.
# This is one of the important findings from which a business can look into, to incur profits and to implement changes in their products.

# %%
sns.distplot(df_recommendations.reset_index().clothing_ID )

# %%
df_recommendations.reset_index().columns
# Out:
# Index(['clothing_ID', 'times_purchased', 'Number_of_times_recommended'], dtype='object')

# %% [markdown]
# Predicting if any item will be recommended

# %%
    df3 = pd.get_dummies(df,columns=['clothing_ID','class_name','dept_name','division_name'])
df3['word_count'] = df.review_text.str.len()
df3.word_count = df3.word_count.replace(NaN, 0)
X = df3.drop(columns=['recommended_IND','review_text' , 'rating','Sentiment_label','Sentiment_score','age_group','age_bin'])
Y=df3.recommended_IND

# %%
dt = tree.DecisionTreeClassifier(max_depth = 3)
dt.fit(X,Y)
# This code will visualize a decision tree dt, trained with the attributes in X and the class labels in Y
dt_feature_names = list(X.columns)
dt_target_names = [str(s) for s in Y.sort_values().unique()]
tree.export_graphviz(
    dt, out_file='tree.dot', 
    feature_names=dt_feature_names, class_names=dt_target_names,
    filled=True)

# %%
os.environ["PATH"] += os.pathsep + 'F:/soft/Graphviz/release/bin/'

# %%
graph = pydotplus.graph_from_dot_file('tree.dot')
Image(graph.create_png())

# %% [markdown]
# ### Interpretting the decision tree
# In the above decision tree we see the trend since the data already displays a huge drift towards with 82% recommendations thus in this decision tree, 7 out of 8 leaf node classify as a particular piece of cloth will be recommended. While only one leaf node demonstrate that cholthing will not be recommended where less than 4 women mark their review as positive, word count in review is less 150 and clothing ID is 838.

# %%
from sklearn.model_selection import KFold

# %%
nfolds = 10

# %%
kf = KFold(n_splits=nfolds,random_state=0,shuffle=True)

# %%
avgCV_AUC = sk.model_selection.cross_val_score(dt,X,Y,cv=kf,n_jobs=-1,\
                                                    scoring='roc_auc').mean()
avgCV_AUC
# Out:
# 0.6893781602231752

# %%
X2 = df3.drop(columns=['recommended_IND','review_text' , 'Sentiment_label','age_group','age_bin'])
Y2=df3.recommended_IND

# %%
dt = tree.DecisionTreeClassifier(max_depth = 4)
dt.fit(X2,Y2)
# This code will visualize a decision tree dt, trained with the attributes in X and the class labels in Y
dt_feature_names = list(X2.columns)
dt_target_names = np.array(Y2.unique(),dtype=np.str) 
tree.export_graphviz(
    dt, out_file='tree1.dot', 
    feature_names=dt_feature_names, class_names=dt_target_names,
    filled=True)

# %%
graph = pydotplus.graph_from_dot_file('tree1.dot')
Image(graph.create_png())

# %%
avgCV_AUC = sk.model_selection.cross_val_score(dt,X2,Y2,cv=kf,n_jobs=-1,\
                                                    scoring='roc_auc').mean()
avgCV_AUC
# Out:
# 0.971866578623097

# %% [markdown]
# Beacuse of high corelation between rating and recommended index Decision tree is baised
